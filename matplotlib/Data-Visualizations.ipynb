# %% [markdown]
# ## ABOUT DATA SET

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

#creating a basic example datasets 
data = {
    
    'Month' : ['jan' , 'Feb'  , 'Mar' , 'Apr' , 'May'] , 
    'Sales' : [150 , 200 , 180 , 220 , 250] , 
    'Expenses' : [80  , 100 , 90 , 110 , 120]
    
}

# %%
import pandas as pd 
df = pd.DataFrame(data )
df
# Out:
#   Month  Sales  Expenses
# 0   jan    150        80
# 1   Feb    200       100
# 2   Mar    180        90
# 3   Apr    220       110
# 4   May    250       120

# %% [markdown]
# # line plots

# %% [markdown]
# - simple line plots

# %%
plt.plot(df['Month'] , df['Sales'])

# %% [markdown]
# ###  adding marker

# %%
plt.plot(df['Month']  , df['Sales']  , marker = 'o')

# %%
plt.plot(df['Month']  , df['Sales']  , marker = 'o')
# o = circle

# %%
# . = point 
plt.plot(df['Month'] , df['Sales'] , marker = '.')

# %%
# p = + (plus)
plt.plot(df['Month'] , df['Sales'] , marker = 'P' )

# %% [markdown]
# ## MOre About Maker

# %%
x = np.random.rand(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x = np.random.rand(10)
#
# NameError: name 'np' is not defined

# %%
fig, axs = plt.subplots(2, 2, sharex=True, sharey=True , figsize = (12 , 7))
#'>'  
axs[0, 0].scatter(df['Month'], df['Sales'] , marker=">")
axs[0, 0].set_title("marker='>'")

#verts 
axs[0 ,1].scatter(df['Month'] , df['Sales'] , marker = verts)
axs[0, 1].set_title("verts")


#astrick 
axs[1, 0 ].scatter(df['Month'] , df['Sales'] , marker=(5, 2))
axs[1, 0].set_title("astrick")

#plus 
axs[1, 1].scatter(df['Month'] , df['Sales'] , marker='P')
axs[1,1 ].set_title("plus")
plt.show()

# %% [markdown]
# ## moving into

# %% [markdown]
# Comprarasion

# %%
plt.plot(df['Month'] , df['Sales'])
plt.plot(df['Month'] , df['Expenses'])

# %% [markdown]
# Adding dots and labels

# %%
plt.plot(df['Month'] , df['Sales'] , marker = 'o' , label = 'Sales')
plt.plot(df['Month'] , df['Expenses'] , marker = 'o' , label = 'Expenses')
plt.xlabel('monthly')
plt.ylabel('Amount')
plt.legend()
plt.show()

# %% [markdown]
# ## coustimazing more with
# - linestyle='-'
# - linewidth=2

# %%
plt.plot(df['Month'] , df['Sales'] , marker = 'o' , label = 'Sales' , linestyle = '-' ,linewidth=2  , markersize = 8  )
plt.plot(df['Month'], df['Expenses'], marker='o', color='black', linestyle='--', linewidth=2, markersize=8, label='Expenses')
plt.legend()
plt.show()

# %% [markdown]
#  # bar plots

# %%
plt.bar(df['Month'] , df['Sales'] , color = "red" , label = 'Sales')
plt.bar(df['Month'] ,df['Expenses'] , color = "black" , label = "Expenses")
plt.legend()

#adding labels 
plt.xlabel('Months')
plt.ylabel('Amount')
plt.title("months , sales and expeses bar chat")
plt.show()

# %%
plt.bar(df['Month'] , df['Sales'] , color = "red" , label = 'Sales')
plt.bar(df['Month'] ,df['Expenses'] , color = "black" , label = "Expenses")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = len(df['Month'])
#       2 plt.bar(df['Month'] , df['Sales'] , color = "red" , label = 'Sales')
#       3 plt.bar(df['Month'] ,df['Expenses'] , color = "black" , label = "Expenses")
#
# NameError: name 'df' is not defined

# %%
x = len(df['Month'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = len(df['Month'])
#
# NameError: name 'df' is not defined
