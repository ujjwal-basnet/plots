# %% [markdown]
# ## ABOUT DATA SET

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

#creating a basic example datasets 
data = {
    
    'Month' : ['jan' , 'Feb'  , 'Mar' , 'Apr' , 'May'] , 
    'Sales' : [150 , 200 , 180 , 220 , 250] , 
    'Expenses' : [80  , 100 , 90 , 110 , 120]
    
}

# %%
import pandas as pd 
df = pd.DataFrame(data )
df
# Out:
#   Month  Sales  Expenses
# 0   jan    150        80
# 1   Feb    200       100
# 2   Mar    180        90
# 3   Apr    220       110
# 4   May    250       120

# %% [markdown]
# # line plots

# %% [markdown]
# - simple line plots

# %%
plt.plot(df['Month'] , df['Sales'])

# %% [markdown]
# ###  adding marker

# %%
plt.plot(df['Month']  , df['Sales']  , marker = 'o')

# %%
plt.plot(df['Month']  , df['Sales']  , marker = 'o')
# o = circle

# %%
# . = point 
plt.plot(df['Month'] , df['Sales'] , marker = '.')

# %%
# p = + (plus)
plt.plot(df['Month'] , df['Sales'] , marker = 'P' )

# %% [markdown]
# ## MOre About Maker

# %%
x = np.random.rand(10)

# %%
fig, axs = plt.subplots(2, 3, sharex=True, sharey=True , figsize = (12 , 5))
#'>' 
axs[0, 0].scatter(df['Month'], df['Sales'] , marker=">")
#verts 
axs[0 ,1].scatter(df['Month'] , df['Sales'] , marker = verts)
#astrick
axs[0, 2 ].scatter(df['Month'] , df['Sales'] , marker=(5, 2))

#plus 
axs[1, 0 ].scatter(df['Month'] , df['Sales'] , marker='P')
