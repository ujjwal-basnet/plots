# %%
#importing
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#importing dataset
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine = fetch_ucirepo(id=109) 
  
# data (as pandas dataframes) 
X = wine.data.features 
y = wine.data.targets

# %%
X
# Out:
#      Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0      14.23       1.71  2.43               15.6        127           2.80
# 1      13.20       1.78  2.14               11.2        100           2.65
# 2      13.16       2.36  2.67               18.6        101           2.80
# 3      14.37       1.95  2.50               16.8        113           3.85
# 4      13.24       2.59  2.87               21.0        118           2.80
# ..       ...        ...   ...                ...        ...            ...
# 173    13.71       5.65  2.45               20.5         95           1.68
# 174    13.40       3.91  2.48               23.0        102           1.80
# 175    13.27       4.28  2.26               20.0        120           1.59
# 176    13.17       2.59  2.37               20.0        120           1.65
# 177    14.13       4.10  2.74               24.5         96           2.05
#
# ...

# %%
y
# Out:
#      class
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 173      3
# 174      3
# 175      3
# 176      3
# 177      3
#
# [178 rows x 1 columns]

# %%
X.columns
# Out:
# Index(['Alcohol', 'Malicacid', 'Ash', 'Alcalinity_of_ash', 'Magnesium',
#        'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols',
#        'Proanthocyanins', 'Color_intensity', 'Hue',
#        '0D280_0D315_of_diluted_wines', 'Proline'],
#       dtype='object')

# %% [markdown]
# ####     Relation between color_intensity and Alcohol

# %%
plt.scatter(x = X['Alcohol'] , y = X['Color_intensity']  , s =  40 ) 
plt.xlabel('Alchol')
plt.ylabel('color_intensity')
plt.title("relation betwen alchol and color_intensity ")
# Out:
# Text(0.5, 1.0, 'relation betwen alchol and color_intensity ')

# %% [markdown]
# - adding alpha = 0.5 and converting color into red

# %%
plt.scatter(x = X['Alcohol'] , y = X['Color_intensity']  , s =  40 , alpha=  0.5 , color  = 'red' )

# %% [markdown]
# ## colormap
# - c represents  a sequence, or sequence of color and its possible values are:
#
#   -  A single color format string.
#    -  A sequence of color specifications of length n.
#   -   A scalar or sequence of n numbers to be mapped to colors using cmap and norm.
#   -   A 2D array in which the rows are RGB or RGBA.

# %%
#some concepts before 
# data set 
import random 
random.seed  = 12 
x = np.random.rand( 5 )
y = np.random.rand( 5)

# %%
# single color format string.
fig, (ax1, ax2) = plt.subplots(1, 2 , figsize = (12 , 5 ))
ax1.scatter(x , y , c = 'red')

ax1.set_title("red color ")

ax2.scatter(x , y , c =  'green')

# %%
fig , (ax1 , ax2) = plt.subplots(1,2 , figsize = (10 , 5 ))

colors = ['red' , 'blue' , 'black' , 'green' , 'yellow']
ax1.scatter(x , y , c = colors )
ax1.set_title("added colors values ")

sizes = [50 , 100 , 20 , 200 , 80  ]
ax2.scatter(x , y  , c = colors , s  = sizes )
ax2.set_title("added sizes ")

plt.show()

# %% [markdown]
# ## Working with C-map and c with
# - you can give 0-99 colors numerical value insted of giving 'red' ,
# - sequential
# - diverging,
# -  cyclic,
# - qualitative,
#  -  miscellaneous

# %%
colors_array = np.arange(5)
print(colors)
plt.scatter(x ,y , c = colors_array , s  = sizes   , cmap ='viridis' ) 
plt.colorbar()
# Out:
# [0 1 2 3 4]

# %% [markdown]
# ## so on ..

# %%
plt.scatter(x = X['Alcohol'] , y = X['Color_intensity']  , s = np.arange(len(X['Color_intensity'])) , alpha=  0.8  ,   cmap='RdPu' , c =X['Color_intensity'])
plt.colorbar()
plt.show()

# %% [markdown]
# Here  Each value in X['Color_intensity'] was  correspond to a color on the colormap specified by cmap.

# %% [markdown]
# ## what if we dont use c = x['']

# %%
plt.scatter(x = X['Alcohol'] , y = X['Color_intensity']  , s =  40 , alpha=  0.8  , c =X['Color_intensity'])
plt.colorbar()
plt.show()
